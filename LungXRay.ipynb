# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/LungXRay'
train_path = dataset_path + '/train'
val_path = dataset_path + '/val'
test_path = dataset_path + '/test'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_path, target_size=(224, 224), batch_size=32, class_mode='binary')
val_generator = val_datagen.flow_from_directory(val_path, target_size=(224, 224), batch_size=32, class_mode='binary')
test_generator = test_datagen.flow_from_directory(test_path, target_size=(224, 224), batch_size=32, class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Build a simple CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(train_generator, epochs=10, validation_data=val_generator)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 887s 5s/step - loss: 0.3740 - accuracy: 0.8451 - val_loss: 0.4551 - val_accuracy: 0.8750
# Epoch 2/10
# 163/163 [==============================] - 387s 2s/step - loss: 0.2313 - accuracy: 0.9013 - val_loss: 0.5011 - val_accuracy: 0.9375
# Epoch 3/10
# 163/163 [==============================] - 380s 2s/step - loss: 0.2243 - accuracy: 0.9097 - val_loss: 0.4955 - val_accuracy: 0.8125
# Epoch 4/10
# 163/163 [==============================] - 392s 2s/step - loss: 0.1936 - accuracy: 0.9224 - val_loss: 0.3733 - val_accuracy: 0.8750
# Epoch 5/10
# 163/163 [==============================] - 387s 2s/step - loss: 0.1884 - accuracy: 0.9254 - val_loss: 0.4233 - val_accuracy: 0.8750
# Epoch 6/10
# 163/163 [==============================] - 379s 2s/step - loss: 0.1706 - accuracy: 0.9323 - val_loss: 0.6542 - val_accuracy: 0.7500
# Epoch 7/10
# 163/163 [==============================] - 385s 2s/step - loss: 0.1737 - accuracy: 0.9319 - val_loss: 0.3587 - val_accuracy: 0.8125
# Epoch 8/10
# 163/163 [==============================] - 382s 2s/step - loss: 0.1527 - accuracy: 0.9373 - val_loss: 0.5841 - val_accuracy: 0.6875
# Epoch 9/10
# 163/163 [==============================] - 370s 2s/step - loss: 0.1368 - accuracy: 0.9473 - val_loss: 1.2251 - val_accuracy: 0.6250
# Epoch 10/10
# 163/163 [==============================] - 389s 2s/step - loss: 0.1426 - accuracy: 0.9448 - val_loss: 0.2193 - val_accuracy: 0.9375

# %%
test_loss, test_acc = model.evaluate(test_generator)
# Out:
# 20/20 [==============================] - 15s 712ms/step - loss: 0.2841 - accuracy: 0.8990
